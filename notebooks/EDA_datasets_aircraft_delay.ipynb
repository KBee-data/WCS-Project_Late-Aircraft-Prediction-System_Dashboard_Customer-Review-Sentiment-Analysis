# %% [markdown]
# # EDA datasets Aircraft Delay

# %% [markdown]
# # imports

# %%
import pandas as pd

import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from datetime import datetime
from datetime import timedelta

# %%
import sys
import os

# Specify the folder containing your Python file, e.g., 'src'
path_to_module = os.path.abspath('../src')  # Adjust the relative path as necessary

sys.path.append(path_to_module)  # Add that path to sys.path

print(f"Module path added: {path_to_module}")
# Out:
# Module path added: /Users/kimberlyblack/Documents/GITHUB-projects/WCS-Project-4/WCS-Project_Late-Aircraft-Prediction-System_Dashboard_Customer-Review-Sentiment-Analysis/src

# %% [markdown]
# # import functions

# %%
from f_summary_stats_df_columns import generate_summary_table

# %%
df_airline_delay_cause = pd.read_csv('/Users/kimberlyblack/Documents/GITHUB-projects/WCS-Project-4/WCS-Project_Late-Aircraft-Prediction-System_Dashboard_Customer-Review-Sentiment-Analysis/data/Airline_Delay_Cause.csv')

df_airlines = pd.read_csv('/Users/kimberlyblack/Documents/GITHUB-projects/WCS-Project-4/WCS-Project_Late-Aircraft-Prediction-System_Dashboard_Customer-Review-Sentiment-Analysis/data/airlines.csv')

df_airports= pd.read_csv('/Users/kimberlyblack/Documents/GITHUB-projects/WCS-Project-4/WCS-Project_Late-Aircraft-Prediction-System_Dashboard_Customer-Review-Sentiment-Analysis/data/airports.csv')

df_cleaned_aircraft_data = pd.read_csv('/Users/kimberlyblack/Documents/GITHUB-projects/WCS-Project-4/WCS-Project_Late-Aircraft-Prediction-System_Dashboard_Customer-Review-Sentiment-Analysis/data/Cleaned_Aircraft_Data.csv')

df_flights = pd.read_csv('/Users/kimberlyblack/Documents/GITHUB-projects/WCS-Project-4/WCS-Project_Late-Aircraft-Prediction-System_Dashboard_Customer-Review-Sentiment-Analysis/data/flights.csv')

df_planes_cleaned = pd.read_csv('/Users/kimberlyblack/Documents/GITHUB-projects/WCS-Project-4/WCS-Project_Late-Aircraft-Prediction-System_Dashboard_Customer-Review-Sentiment-Analysis/data/df_planes_cleaned.csv')
# Out:
# /var/folders/kl/2y01c7y51cj42bdww37cvc5c0000gn/T/ipykernel_12881/1394024305.py:9: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_flights = pd.read_csv('/Users/kimberlyblack/Documents/GITHUB-projects/WCS-Project-4/WCS-Project_Late-Aircraft-Prediction-System_Dashboard_Customer-Review-Sentiment-Analysis/data/flights.csv')

# %%
generate_summary_table(df_flights)
# Out:
#             Column Name Data Type  Missing Values  % Missing Values  \
# 0                  YEAR     int64               0          0.000000
# 1                 MONTH     int64               0          0.000000
# 2                   DAY     int64               0          0.000000
# 3           DAY_OF_WEEK     int64               0          0.000000
# 4               AIRLINE    object               0          0.000000
# 5         FLIGHT_NUMBER     int64               0          0.000000
# 6           TAIL_NUMBER    object           14721          0.252978
# 7        ORIGIN_AIRPORT    object               0          0.000000
# 8   DESTINATION_AIRPORT    object               0          0.000000
# 9   SCHEDULED_DEPARTURE     int64               0          0.000000
# 10       DEPARTURE_TIME   float64           86153          1.480526
# 11      DEPARTURE_DELAY   float64           86153          1.480526
# 12             TAXI_OUT   float64           89047          1.530259
# ...
